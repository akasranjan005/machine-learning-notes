# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
colnames=['charge','backup']
df=pd.read_csv('trainingdata.txt',names=colnames)

# %%
df.head()
# Out:
#    charge  backup
# 0    2.81    5.62
# 1    7.14    8.00
# 2    2.72    5.44
# 3    3.87    7.74
# 4    1.90    3.80

# %%
fig_size = list(plt.rcParams["figure.figsize"])
fig_size[0] = 18
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

# %%
plt.scatter(df['charge'],df['backup'])

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# Out:
# /Library/Python/2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Charge vs Backup (Training set)')
plt.xlabel('Charge')
plt.ylabel('Backup')
plt.show()

# %% [markdown]
# # Applying polynomial Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 3)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Charge')
plt.ylabel('Bacup')
plt.show()

# %%
lin_reg_2.predict(poly_reg.fit_transform(1.5))
# Out:
# array([ 3.19136839])

# %%
print lin_reg_2.predict(poly_reg.fit_transform(0))
# Out:
# [-0.37512503]

# %%
df.head()
# Out:
#    charge  backup
# 0    2.81    5.62
# 1    7.14    8.00
# 2    2.72    5.44
# 3    3.87    7.74
# 4    1.90    3.80

# %% [markdown]
# # Fitting the data

# %%
df2=df.loc[df['charge'] <= 4].sort_values('charge')

# %%
X2 = df2.iloc[:, :-1].values
y2 = df2.iloc[:, 1].values

# %%
#from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X2, y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X2)

# %%
plt.scatter(X2, y2, color = 'red')
plt.plot(X2, regressor.predict(X2), color = 'blue')
plt.title('Charge vs Backup (Training set)')
plt.xlabel('Charge')
plt.ylabel('Backup')
plt.show()

# %%
print regressor.predict(0.09)[0]
# Out:
# 0.18
